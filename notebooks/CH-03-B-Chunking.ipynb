# %% [markdown]
# # Desafío 03-B-Chunking

# %% [markdown]
# ## 1. Descripción general
#
# En este cuaderno, repasarás los conceptos de tokens y chunking. En el cuaderno anterior (CH-03-A-Grounding), pudimos proporcionar algo de contexto adicional para fundamentar el modelo. ¿Existe un límite para la cantidad de contexto adicional que podemos proporcionar al modelo? Desafortunadamente, la respuesta es sí. Existe un límite para la cantidad de tokens permitidos en la entrada y la salida combinadas según el modelo que se esté utilizando.
#
# Entonces, ¿qué son los tokens? Los tokens son una representación de cómo los modelos de Azure OpenAI procesan el texto. Son palabras o simplemente fragmentos de caracteres. Veamos el número total de tokens en la respuesta que obtuvimos del primer cuaderno en CH-03. Hay muchas formas de calcular tokens. En este cuaderno, echaremos un vistazo a la biblioteca `token` para contar los tokens.

# %% [markdown]
# ## 2. Empecemos la Implementación
#
# Necesitarás importar los módulos necesarios. Las siguientes celdas son pasos clave de configuración que completaste en los desafíos anteriores.

# %%
! pip install --upgrade click
! python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: click in /usr/local/python/3.10.13/lib/python3.10/site-packages (8.1.7)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 73.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.2)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import openai
import PyPDF3
import os
import json
import tiktoken
import spacy
from openai.error import InvalidRequestError

from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

from spacy.lang.en import English 
nlp = spacy.load("en_core_web_sm")

import langchain
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# Configura tu entorno para acceder a tus claves de Azure OpenAI. Consulta tu recurso de Azure OpenAI en el Portal de Azure para obtener información sobre tu punto final y claves de Azure OpenAI.
#
# Por razones de seguridad, almacena tu información sensible en un archivo .env.

# %%
# Load your OpenAI credentials
API_KEY = os.getenv("OPENAI_API_KEY")
assert API_KEY, "ERROR: Azure OpenAI Key is missing"
openai.api_key = API_KEY

RESOURCE_ENDPOINT = os.getenv("OPENAI_API_BASE","").strip()
assert RESOURCE_ENDPOINT, "ERROR: Azure OpenAI Endpoint is missing"
assert "openai.azure.com" in RESOURCE_ENDPOINT.lower(), "ERROR: Azure OpenAI Endpoint should be in the form: \n\n\t<your unique endpoint identifier>.openai.azure.com"
openai.api_base = RESOURCE_ENDPOINT

openai.api_type = os.getenv("OPENAI_API_TYPE")
openai.api_version = os.getenv("OPENAI_API_VERSION")
model=os.getenv("CHAT_MODEL_NAME")

# %% [markdown]
# ## 3. Conteo de Tokens
#
# Tiktoken utiliza una técnica llamada codificación de pares de bytes (BPE) para convertir el texto dado en tokens. Hay diferentes codificaciones disponibles para ayudar a procesar las palabras. En este cuaderno, utilizaremos el cl100k_base.
#
# #### Tarea del Estudiante #1:
#
# Cuenta el número de tokens en la respuesta final que recibimos en CH-03-A-Grounding completando la función, count_tokens, a continuación.

# %%
def count_tokens(string: str, encoding_name: str) -> int:
    encoder = tiktoken.get_encoding(encoding_name)
    tokens = encoder.encode(string)

    return len(tokens)

# %% [markdown]
# #### Tarea del Estudiante #2:
#
# Ingresa el texto de la respuesta que recibiste en CH-03-A-Grounding. Ejecuta la celda a continuación para recuperar el número de tokens utilizando la función count_tokens.

# %%
text = """Los ganadores de los partidos individuales tanto masculinos como femeninos del Wimbledon del 2023 fueron:

- En la sección masculina, Carlos Alcaraz ganó el partido final contra Novak Djokovic.
- En la sección femenina, Marketa Vondrousova se impuso en la final a Ons Jabeur."""

count_tokens(text, "cl100k_base")

print("Hay " + str(count_tokens(text, "cl100k_base")) + " tokens: " + text)
# Out:
# Hay 77 tokens: Los ganadores de los partidos individuales tanto masculinos como femeninos del Wimbledon del 2023 fueron:
#
# - En la sección masculina, Carlos Alcaraz ganó el partido final contra Novak Djokovic.
# - En la sección femenina, Marketa Vondrousova se impuso en la final a Ons Jabeur.

# %% [markdown]
# De acuerdo, ahora sabemos con cuántos tokens estamos trabajando. ¿Qué sucede si queremos agregar más contexto que el que ya pusimos en la variable de texto anterior? Si pensamos en nuestro escenario de Wimbledon, necesitaremos darle al modelo más contexto para ayudarlo a entender todo lo que necesita saber sobre el torneo. Más importante aún, todo lo que necesita saber para ayudar a responder tus preguntas al escribir el informe. Digamos que queremos proporcionar más contexto al modelo con un documento PDF. ¿Podemos intentar obtener un resumen del documento PDF para ayudarnos con nuestro trabajo?

# %% [markdown]
# #### Tarea del Estudiante #3:
#
# En la celda siguiente, inserta la ruta del documento PDF, `CH3-data.pdf`, que se encuentra en la carpeta `/data` proporcionada. Ejecuta las tres celdas para ver la salida.

# %%
document = open(r'/workspaces/wth-openia/data/CH3-data.pdf', 'rb') 
doc_helper = PyPDF3.PdfFileReader(document)

# %%
finaltext = ''
totalpages = doc_helper.getNumPages()
for eachpage in range(totalpages):
   p = doc_helper.getPage(eachpage)
   indpagetext = p.extractText()
   finaltext += indpagetext

clean_text = finaltext.replace("  ", " ").replace("\n", "; ").replace(';',' ')

# %%
prompt = f"What is the answer to the following question regarding the PDF document?\n\n{finaltext}\n\n" 
q = "Can you give me a summary of the document?"

try:
    final_prompt = prompt + q
    messages = [{"role": "system", "content": "You are a helpful assistant."}, {"role": "user", "content": final_prompt}]
    response = openai.ChatCompletion.create(engine=model, messages=messages, max_tokens=50)
    answer = response.choices[0].text.strip()
    print(f"{q}\n{answer}\n")

except InvalidRequestError as e:
    print(e.error)
# Out:
# {
#   "code": "context_length_exceeded",
#   "message": "This model's maximum context length is 4096 tokens. However, your messages resulted in 39503 tokens. Please reduce the length of the messages.",
#   "param": "messages",
#   "type": "invalid_request_error"
# }

# %% [markdown]
# Como verás arriba, recibirás un mensaje de error después de ejecutar el fragmento de código anterior. El modelo alcanza su longitud de contexto máxima. Para los modelos GPT-3, el límite de tokens es de 4097 tokens. ¿Cómo solucionamos este problema al proporcionarle todo el contexto necesario, pero sin encontrarnos con el problema del límite de tokens?
#
# Para resolver este problema, podemos echar un vistazo a un concepto llamado Chunking.

# %% [markdown]
# ## 4. Chunking
#
# El chunking ayuda a limitar la cantidad de información que pasamos al modelo. La información que pasaremos son los trozos más relevantes de los datos en general. Hay muchas consideraciones que entran en juego al hacer chunking. Por ejemplo, necesitas averiguar el mejor tamaño de chunk. Si los trozos son demasiado pequeños, puedes perder contexto importante. Si los trozos son demasiado grandes, pueden contener información innecesaria.
#
# A continuación se presentan algunas técnicas comunes de chunking.
#
# 1. Chunking con trozos más pequeños
# 2. Chunking dividiendo las oraciones
# 3. Chunking con superposición de oraciones
# 4. Chunking de forma recursiva
#
# Veamos estas técnicas en acción.

# %% [markdown]
# ### 4.1 Chunking con trozos más pequeños
#
# #### Tarea del Estudiante #4:
#
# Agrega código en la celda siguiente. Utiliza la función split() para dividir el texto en trozos.

# %%
text = "The sun was setting over the horizon, casting a warm glow over the landscape. Birds chirped in the trees, and a gentle breeze rustled the leaves. In the distance, a herd of deer grazed in a meadow. The air was filled with the sweet scent of blooming flowers. It was a peaceful and serene scene, perfect for a quiet evening stroll."

text2 = text.split('.')
# Out:
# ['The sun was setting over the horizon, casting a warm glow over the landscape',
#  ' Birds chirped in the trees, and a gentle breeze rustled the leaves',
#  ' In the distance, a herd of deer grazed in a meadow',
#  ' The air was filled with the sweet scent of blooming flowers',
#  ' It was a peaceful and serene scene, perfect for a quiet evening stroll',
#  '']

# %% [markdown]
# ¿Qué puedes observar sobre los trozos devueltos? ¿Si cada trozo estuviera por sí mismo, podrías entender el significado semántico?

# %% [markdown]
# ### 4.2: Chunking dividiendo las oraciones
#
# #### Tarea del Estudiante #5:
#
# Agrega código en la celda siguiente. Utiliza la biblioteca spacy y específicamente la función sents para dividir el texto en trozos.

# %%
text = "Today was a fun day. I had lots of ice cream. I also met my best friend Sally and we played together at the new playground."

doc = nlp(text)
sentences = list(doc.sents)

# %%
sentences
# Out:
# [Today was a fun day.,
#  I had lots of ice cream.,
#  I also met my best friend Sally and we played together at the new playground.]

# %% [markdown]
# ¿Los resultados son mejores que el método en 4.1? La biblioteca spaCy ayuda a dividir el texto en oraciones individuales. Esto puede ser útil cuando intentas hacer resúmenes de texto. Puedes clasificar las oraciones individuales y usar los mejores resultados en el resumen.

# %% [markdown]
# ### 4.3: Chunking con superposición de oraciones
#
# #### Tarea del Estudiante #6:
#
# Ejecuta el código a continuación para ver otro ejemplo de chunking. Como verás, el significado semántico se mantiene. En otras palabras, se conserva el contexto entre las oraciones. Esto es especialmente importante cuando estás buscando datos para obtener resultados relevantes o cuando estás resumiendo un fragmento de texto. Es importante capturar las relaciones entre las oraciones.

# %%
text = "The sun was setting over the horizon, casting a warm glow over the landscape. Birds chirped in the trees, and a gentle breeze rustled the leaves. In the distance, a herd of deer grazed in a meadow. The air was filled with the sweet scent of blooming flowers. It was a peaceful and serene scene, perfect for a quiet evening stroll."
doc = nlp(text)

sentences = list(doc.sents)
overlap = 1
chunks =[]

for i in range(len(sentences) - overlap):
    chunk = sentences[i : i + overlap + 1]
    chunks.append(chunk)

for chunk in chunks:
    print([sent.text for sent in chunk])
# Out:
# ['The sun was setting over the horizon, casting a warm glow over the landscape.', 'Birds chirped in the trees, and a gentle breeze rustled the leaves.']
# ['Birds chirped in the trees, and a gentle breeze rustled the leaves.', 'In the distance, a herd of deer grazed in a meadow.']
# ['In the distance, a herd of deer grazed in a meadow.', 'The air was filled with the sweet scent of blooming flowers.']
# ['The air was filled with the sweet scent of blooming flowers.', 'It was a peaceful and serene scene, perfect for a quiet evening stroll.']

# %% [markdown]
# ### 4.4: Chunking de forma recursiva usando LangChain
#
# #### Tarea del Estudiante #7:
#
# Agrega los parámetros requeridos para RecursiveCharacterSplitter en la celda siguiente.

# %%
split_text = RecursiveCharacterTextSplitter(
   chunk_size=100,
   chunk_overlap=20,
   length_function=len,
   is_separator_regex=False,
)
docs = split_text.create_documents([clean_text])
docs
# Out:
# [Document(page_content='Formula 1 Power Unit Financial Regulations     1     16 August     2022     © 202  2'),
#  Document(page_content='202  2                Issue   1              FORMULA 1   POWER UNIT   FINANCIAL REGULATIONS'),
#  Document(page_content='REGULATIONS     PUBLISHED ON   16 August     2022     Issue   1        CONTENTS        Art'),
#  Document(page_content='Art     CONTENTS     Page(s)     1.     GENERAL PRINCIPLES'),
#  Document(page_content='PRINCIPLES     ................................  ................................'),
#  Document(page_content='................................  ........     2     2.     POWER UNIT MANUFACTURER OBLIGATIONS'),
#  Document(page_content='OBLIGATIONS     ................................  ................................  ....     3'),
#  Document(page_content='....     3     3.     EXCLUSIONS     ................................'),
#  Document(page_content='................................  ................................  .....................     5'),
#  Document(page_content='5     4.     ADJUSTMENTS     ................................  ................................'),
#  Document(page_content='................................  ..................     8     5.     REPORTING R  EQUIREMENTS'),
#  Document(page_content='R  EQUIREMENTS     ................................  ................................'),
#  Document(page_content='...........................     12     6.     COST CAP ADMINISTRATION'),
#  Document(page_content='ADMINISTRATION     ................................  ................................'),
#  Document(page_content='...........................     14     7.     COST CAP ADJUDICATION PANEL'),
#  Document(page_content='PANEL     ................................  ................................  .....................'),
#  Document(page_content='19     8.     CATEGORIES OF BREACH     ................................'),
#  Document(page_content='................................  ................................  .     23     9.     SANCTIONS'),
#  Document(page_content='9.     SANCTIONS FOR BREACH  ................................  ................................'),
#  Document(page_content='................................  .     26     APPENDIX 1 DEFINITIONS AND INTERPRETATION'),
#  Document(page_content='AND INTERPRETATION  ................................  ................................  .........'),
#  Document(page_content='.........     29     APPENDIX 2 ELIGIBLE TEST BENCHES     ................................'),
#  Document(page_content='................................  ...........................     51     APPENDIX 3 TRANSITIONAL'),
#  Document(page_content='3 TRANSITIONAL CAPITAL EXPENDITURE QUALIFYING ASSETS     ................................  ......'),
#  Document(page_content='......     56                 Formula 1 Power Unit Financial Regulations     2     16 August'),
#  Document(page_content='2     16 August     2022     © 202  2                Issue   1           1.     GENERAL PRINCIPLES'),
#  Document(page_content='GENERAL PRINCIPLES      Scope     1.1     These   Power Unit   Financial Regulations     come into'),
#  Document(page_content='come into force   on     1 January   202  3  . They form part of   the terms and conditions'),
#  Document(page_content='and conditions   for   the   homologation   of   Power Units to   be supplied to     F1 Team  s'),
#  Document(page_content='F1 Team  s     for     participation in the Championship     from 2026 onwards  . Each   Power'),
#  Document(page_content='. Each   Power Unit Manufacturer     intending to homologate Power Units     for supply   to an'),
#  Document(page_content='supply   to an   F1 Team  (s)     for   participat  ion     in the   Championship   from 2026'),
#  Document(page_content='from 2026 onwards   agrees to be bound by  ,     and   undertakes   to comply with  ,     these'),
#  Document(page_content='with  ,     these   Power Unit   Financial Regulations     from   the start of   its N  -  3 Full'),
#  Document(page_content='its N  -  3 Full Year Reporting Period  .     Objectives     1.2     These   Power Unit'),
#  Document(page_content='Power Unit   Financial Regulations     introduce a   Power Unit   Cost Cap that limits   certain'),
#  Document(page_content='limits   certain   costs     that may be   incurred by or on behalf of   a Power Unit Manufacturer'),
#  Document(page_content='Unit Manufacturer   in each   Full Year   Reporting Period, while leaving   that   Power Unit'),
#  Document(page_content='that   Power Unit Manufacturer   free to decide how to allocate   resources within that   Power'),
#  Document(page_content='within that   Power Unit   Cost C  ap.      1.3     These   Power Unit   Financial Regulations are'),
#  Document(page_content='Regulations are     designed to   help   achieve the following   objectives   (the   "  Objectives'),
#  Document(page_content='"  Objectives  "  )  :     (a)     to promote   the   long  -  term   competitive balance of the'),
#  Document(page_content='balance of the Championship     in respect of   Power Units        (b)     to   promote the   long'),
#  Document(page_content='promote the   long  -  term   sporting fairness     of the Championship     in respect of Power'),
#  Document(page_content='respect of Power   Units        and     (c)     to   ensure   the long  -  term financial'),
#  Document(page_content='term financial     stability and     sustainability of the   Power Unit   Manufacturers  ,'),
#  Document(page_content=',        while   preserv  ing     the     unique technolog  y and engineering challenge     of F'),
#  Document(page_content='challenge     of F  ormula   1  .     1.4     These   Power Unit   Financial Regulations     wi  ll'),
#  Document(page_content='wi  ll be interpreted and applied by the     Cost Cap   Administration  , the Cost Cap'),
#  Document(page_content=', the Cost Cap Adjudication Panel and the ICA   in a consistent manner that treats   all     Power'),
#  Document(page_content='all     Power Unit Manufacturers     equally and that   advances   the Objectives  .     1.5'),
#  Document(page_content='.     1.5     The definitive version of these   Power Unit   Financial Regulations     is the'),
#  Document(page_content='is the English version, which   will be used should any dispute arise as to their'),
#  Document(page_content='arise as to their interpretation. Defined w  ords and phrases in   these   Power Unit   Financ  ial'),
#  Document(page_content='Unit   Financ  ial Regulations     (denoted by initial capital letters) have the meaning'),
#  Document(page_content='have the meaning   indicated     in     Appendix   1   to these   Power Unit   Financial'),
#  Document(page_content='Unit   Financial Regulations  , unless otherwise defined   in the body of these   Power Unit'),
#  Document(page_content='Power Unit   Financial Regulations  .     Unless otherwise specified, references   to   "'),
#  Document(page_content='to   "  Articles  "     are to Articles     of these   Power Unit   Financial Regulations  ,'),
#  Document(page_content='Regulations  ,     references to "may"   shall mean in the sole discretion of such person or entity'),
#  Document(page_content='person or entity (as the context so requires),   and any   phrase introduced by the t  erms'),
#  Document(page_content='by the t  erms "including", "include", "in particular" or any similar expression   shall be'),
#  Document(page_content='shall be construed as illustrative and not   as   limit  ing     the sense of the words preceding'),
#  Document(page_content='the words preceding those   terms.        1.6     If any part of these   Power Unit   Financial'),
#  Document(page_content='Unit   Financial Regulations     is found by a court or authority of   competent jurisdiction to be'),
#  Document(page_content='jurisdiction to be illegal, invalid or unenforceable, that part will be deemed not to   form part'),
#  Document(page_content='not to   form part of these   Power Unit   Financial Regulations  , and the legality, validity or'),
#  Document(page_content='validity or enforceability   of the remainder of these     Power Unit   Financial Regulations'),
#  Document(page_content='Regulations     will not be affected.        Formula 1 Power Unit Financial Regulations     3'),
#  Document(page_content='3     16 August     2022     © 202  2                Issue   1           1.7     The Cost Cap'),
#  Document(page_content='The Cost Cap   Administration     shall periodically review these   Power Unit   Financial'),
#  Document(page_content='Unit   Financial Regulations  .   The  se   Power Unit   Financial Regulations     may be amen  ded'),
#  Document(page_content='may be amen  ded and/or supplemented by the FIA   World   Motor     S  port Cou  ncil from time'),
#  Document(page_content='Cou  ncil from time to time  .     Accountability      1.8     Each   Power Unit Manufacturer'),
#  Document(page_content='Unit Manufacturer   must   ensure that all Personnel are made   aware:     (a)     of the'),
#  Document(page_content='(a)     of the Objectives, content and substance of these   Power Unit   Financial Regulations'),
#  Document(page_content='Regulations        and     (  b  )         that the   Power Unit Manufacturer     is subject to'),
#  Document(page_content='is subject to these   Power Unit   Financial Regulations.     1.9     E  ach   Power Unit'),
#  Document(page_content='E  ach   Power Unit Manufacturer     must   ensure that   all relevant   Personnel are'),
#  Document(page_content='Personnel are appropriately   informed and trained with respect to the ways in which their areas'),
#  Document(page_content='which their areas of responsibility may   impact the   Power Unit Man  ufacturer    se     Power'),
#  Document(page_content='se     Power   Unit   Financial   Regulations.      1.10     E  ach   Power Unit Manufacturer'),
#  Document(page_content='Manufacturer     must   ensure that   the FIA     ethics and compliance   policy in force   from'),
#  Document(page_content='in force   from time to time with respect to these   Power Unit   Financial Regulations is clearly'),
#  Document(page_content='is clearly   communicated to all Personnel.     2.     POWER UNIT MANUFACTURER     OBLIGATIONS'),
#  Document(page_content='OBLIGATIONS     2.1     Each   Power Unit Manufacturer     must  :     (a)     demonstrate its'),
#  Document(page_content='demonstrate its ongoing compliance with the   Power Unit   Cost Cap by submitting   Reporting'),
#  Document(page_content='Reporting Documentation in respect of its Reporting Group to the Cost Cap   Ad  ministration'),
#  Document(page_content='ministration     by the Reporting Deadline in   respect of   each Reporting Period and by'),
#  Document(page_content='Period and by   providing any further information requested from time to time by the Cost Cap'),
#  Document(page_content='by the Cost Cap   Administration         (b)     cooperate fully and   in a timely manner   with'),
#  Document(page_content='manner   with     the Cost Cap Administration in     the   exercise of   its     regulatory'),
#  Document(page_content='its     regulatory function, including   any investigation conducted by or on   behalf of the Cost'),
#  Document(page_content='behalf of the Cost Cap   Administration     pursuant to     these   Power Unit   Financial'),
#  Document(page_content='Unit   Financial   Regulations     and/or with the Financial Regulations           (c)     provide'),
#  Document(page_content='(c)     provide any information     and documentation     requested by or on behalf of the Cost'),
#  Document(page_content='behalf of the Cost   Cap Administration   relevant to any actual  ,     potential     or'),
#  Document(page_content='potential     or   suspected     instance of non  -  compliance with these   Power Unit'),
#  Document(page_content='Power Unit   Financial Regulations     and/or with the Financial   Regulations    and     (d)'),
#  Document(page_content='and     (d)     faithfully execute its obligations und  er these   Power Unit   Financial'),
#  Document(page_content='Unit   Financial Regulations     and act     at all times     in     a spirit of     G  ood   F'),
#  Document(page_content='of     G  ood   F  aith and   cooperation  .        Cap     on Relevant Costs     2.2     A'),
#  Document(page_content='2.2     A     Power Unit Manufacturer   must  :     (a)     determine and report     its'),
#  Document(page_content='and report     its Relevant Costs against the   Power Unit   Cost Cap in the   Power   Unit'),
#  Document(page_content='Power   Unit   Manufacturer      and        Formula 1 Power Unit Financial Regulations     4'),
#  Document(page_content='4     16 August     2022     © 202  2                Issue   1           (b)     not   have'),
#  Document(page_content='not   have     Relevant Costs   in excess of the   Power Unit   Cost Cap   in   the applicable'),
#  Document(page_content='the applicable     Full   Year   Reporting Period  .     The   Power Unit   Cost Cap     2.3'),
#  Document(page_content='Cap     2.3     The amount of the "  Power Unit     Cost Cap  " shall be     as follows  :     (a)'),
#  Document(page_content='follows  :     (a)     in the Full Year   Reporting Period  s     ending on 31 December 202  3, 31'),
#  Document(page_content='December 202  3, 31 December 2024   and 31 December 2025  , US Dollars 95,000,000  , adjusted for'),
#  Document(page_content=', adjusted for Indexation        and     (b)     in the Full Year Reporting Period ending on 31'),
#  Document(page_content='Period ending on 31 December 202  6     and in each subsequent   Full Year Reporting Period  , US'),
#  Document(page_content='Period  , US Doll  ars 130,000,000  , adjusted for Indexation  .     2.4     Where a   Power Unit'),
#  Document(page_content='a   Power Unit Manufacturer   has a Presentation Currency other than US Dollars, the   Power Unit'),
#  Document(page_content='the   Power Unit   Cost Cap for that   Power Unit Manufacturer     shall be converted from US'),
#  Document(page_content='converted from US Dollars   into   that   Power Unit Manufacturer       Presentation Currency at'),
#  Document(page_content='Currency at the Initial Applicable Rate. For   illustrative purposes, the amount of the   Power'),
#  Document(page_content='of the   Power Unit   Cost Cap in selected Presentation   Currencies for the Full Year Reporting'),
#  Document(page_content='Full Year Reporting Period   ending on 31 December 202  3  , as   referred to in   Article   2.3'),
#  Document(page_content='in   Article   2.3  (a)   (as  suming Indexation of zero)   is     as follows:     US Dollars'),
#  Document(page_content='US Dollars           Pounds Sterling           Euros           95,000     76,459     90,210'),
#  Document(page_content='90,210        Reporting Group     2.5     F  or   the   purposes of   reporting   Total'),
#  Document(page_content='Total     Costs     of the Reporting Group  ,     a     Power Unit   Manufacturer       Reporting'),
#  Document(page_content='Reporting Group     shall   comprise the   Power Unit Manufacturer     together with  ,'),
#  Document(page_content='together with  ,   where the   Power Unit Manufacturer     has incurred less than 95% of the costs'),
#  Document(page_content='95% of the costs of the   Power Unit   Activities undertaken by or on behalf of the   Power Unit'),
#  Document(page_content='of the   Power Unit Manufacturer     in the Reporting Period,     such   additional   en  tities'),
#  Document(page_content="en  tities within the   Power Unit Manufacturer  's Legal G  ro  up S  tructure     as are"),
#  Document(page_content='as are   determined in accordance with     Article   2.6  .     2.6     The   additional'),
#  Document(page_content='The   additional   entities to be included within   the     Reporting Group   where   a     Power'),
#  Document(page_content='where   a     Power Unit   Manufacturer     has incurred less than 95% of the costs of the   Power'),
#  Document(page_content='of the   Power Unit   Activities undertaken   by or on behalf of   that   Power Unit Manufacturer'),
#  Document(page_content='Unit Manufacturer     in the Reporting Period   shall be     the entity   (other than the   Power'),
#  Document(page_content='than the   Power Unit Manufacturer  ) within the   Power Unit Manufacturer    Structure that'),
#  Document(page_content='Structure that incurred the greatest amount of costs     of the   Power Unit   Activities'),
#  Document(page_content='Unit   Activities undertaken   by or on behalf of the   Power Unit Manufacturer     in the'),
#  Document(page_content='in the Reporting Period  , followed   (to the   extent required)   by   the entity     within'),
#  Document(page_content='entity     within the   Power Unit Manufacturer    that incurred     the next greatest amou  nt of'),
#  Document(page_content='amou  nt of   such   costs, and so on, until   the entities included   within   the     Reporting'),
#  Document(page_content='the     Reporting Group have     incurred  ,     in aggregate, 95%   or more   of the costs of'),
#  Document(page_content='of the costs of the   Power   Unit   Activities undertaken by or on behalf of the   Power Unit'),
#  Document(page_content='of the   Power Unit Manufacturer     in the Reporting   Period.      2.7     I  n addition to those'),
#  Document(page_content='n addition to those   entities   included     in the Reporting Group   pursuant to Article  s'),
#  Document(page_content='to Article  s     2.5     and   2.6  ,   a     Power Unit Manufacturer     may elect to include'),
#  Document(page_content='elect to include additional entities in its Reporting Group      Formula 1 Power Unit Financial'),
#  Document(page_content='Unit Financial Regulations     5     16 August     2022     © 202  2                Issue   1'),
#  Document(page_content='Issue   1           from     w  ithin its Legal Group Structure     which have incurred costs'),
#  Document(page_content='have incurred costs of   Power Unit   Activities   undertaken on behalf of the   Power Unit'),
#  Document(page_content='of the   Power Unit Manufacturer     in the Reporting Period  .     2.8     For the purposes of'),
#  Document(page_content='For the purposes of Articles     2.5     to     2.7     (inclusive)  ,     t  he calculation of the'),
#  Document(page_content='calculation of the costs of   Power Unit   Activities undertaken by or on behalf of the   Power'),
#  Document(page_content='of the   Power Unit Manufacturer     in the Reporting Period:     (a)     shall not include'),
#  Document(page_content='shall not include   Finance Costs and   costs Directly Attributable to Marketing   Activities'),
#  Document(page_content='Activities        (b)     shall be made having adjusted   out     any amounts in connection with'),
#  Document(page_content='in connection with   Power Unit   Activities recharged from one member of the   Power Unit'),
#  Document(page_content='of the   Power Unit Manufacturer    egal Group   Structure to another  .     2.9     I  n th  e'),
#  Document(page_content='I  n th  e     calculation of Relevant Costs, the costs of any   Power Unit   Activities'),
#  Document(page_content="Unit   Activities   incurred by     entities   within the   Power Unit Manufacturer  's Legal Group"),
#  Document(page_content="'s Legal Group Structure but outside its Reporting Group  ,   other than   Finance Costs and"),
#  Document(page_content='Finance Costs and   costs Directly Attributable to   Marketing   Activities undertaken   by any'),
#  Document(page_content='undertaken   by any such entity,     must either be:     (a)     recharged a  t Fair Value to a'),
#  Document(page_content='Fair Value to a     Reporting Group     Entity and thereby included within Total   Costs     of the'),
#  Document(page_content='Costs     of the Reporting Group    or      (b)     included   in Relevant Costs   at Fair Value'),
#  Document(page_content='at Fair Value by   way of an Adjustment to Total     Cost  s     of the   Reporting Group  , as a'),
#  Document(page_content='Group  , as a Related Party Transaction pursuant to Article 4.1(a)(i)  .     2.10     The   Power'),
#  Document(page_content='The   Power Unit Manufacturer     should seek clarification from the Cost Cap Administration if'),
#  Document(page_content='Administration if it   is uncertain whether an entity should be included in its Reporting Group.'),
#  Document(page_content='Reporting Group.     3.     E  XCLUSIONS     3.1     In calculating     Relevant Costs  ,     t  he'),
#  Document(page_content='Costs  ,     t  he following   costs and   amounts     within Total Costs     of the   Reporting'),
#  Document(page_content='of the   Reporting Group   must     be excluded     (  "  Excluded Costs  "  )  :     (a)     A'),
#  Document(page_content=')  :     (a)     A  ll costs   D  irectly   A  ttributable to Marketing Activities        (b)'),
#  Document(page_content='(b)     With respect to Heritage Asset Activities:     (i)     a  ll costs   D  irectly   A'),
#  Document(page_content='D  irectly   A  ttributable to Heritage Asset Activities        and     (ii)     if the Power'),
#  Document(page_content='if the Power Unit Manufacturer can prove to the satisfaction of   the   Cost Cap'),
#  Document(page_content='the   Cost Cap   Administration that an identifiable portion of the Consideration provided to'),
#  Document(page_content='provided to   any Heritage Asset Personnel relates   to Heritage Asset Activities, that portion'),
#  Document(page_content='that portion     contributions      (c)     All   Finance     Costs        (d)     A  ll'),
#  Document(page_content='(d)     A  ll   Corporate Income Tax        (e)     With respect to Non  -  Power Unit'),
#  Document(page_content='-  Power Unit   Activities:      (i)     a  ll costs   D  irectly   A  ttributable to   Non  -'),
#  Document(page_content='to   Non  -  Power Unit   Activities    and        Formula 1 Power Unit Financial Regulations     6'),
#  Document(page_content='Regulations     6     16 August     2022     © 202  2                Issue   1           (ii)'),
#  Document(page_content='(ii)     if     the   Power Unit Manufacturer     can prove to the satisfaction of the'),
#  Document(page_content='satisfaction of the Cost Cap   Administration     that an identifiable portion of     the following'),
#  Document(page_content='the following costs     relates to     Non  -  Power Unit   Activities  , that portion of those'),
#  Document(page_content='portion of those costs  :     (A)     Consideration   provided to  ,       contributions incurred'),
#  Document(page_content='incurred in respect of  ,     an  y Personnel     engaged in     both     Power Unit   Activities'),
#  Document(page_content='Unit   Activities     and   Non  -  Power Unit   Activities        (B)     e  lectricity, gas   and'),
#  Document(page_content='gas   and   water     costs     incurred     in the cours  e of both   Power   Unit   Activities'),
#  Document(page_content='Unit   Activities and Non  -  Power Unit   Activities         (C)     lease costs in respect of'),
#  Document(page_content='costs in respect of plant and equipment     used in the cours  e of   both   Power Unit'),
#  Document(page_content='both   Power Unit   Activities and Non  -  Power Unit   Activities        and     (D)     costs of'),
#  Document(page_content='(D)     costs of   parts and consumables  ,     and   outsourced     service  s  ,     incurred'),
#  Document(page_content='s  ,     incurred for   the     maintenance of   an item of   plant or equipment used in the'),
#  Document(page_content='used in the course   of both   Power Unit   Activities and Non  -  Power Unit   Activities      (f)'),
#  Document(page_content='Activities      (f)     All costs   D  irectly   A  ttributab  le to Human Resources Activit  ies'),
#  Document(page_content='Activit  ies  ,     Finance Act  ivit  ies     or     Legal Activit  ies        (g)     All'),
#  Document(page_content='(g)     All Property   Cost  s        (h)     All   Employee     Bonus Costs  , subject to a'),
#  Document(page_content=', subject to a maximum   amount     in any Full Year Reporting   Period   of     the lower of  :'),
#  Document(page_content='the lower of  :        (i)       20  % of the   Total   Fixed   Employee     Remuneration'),
#  Document(page_content='Remuneration        and           (ii)     US Dollars 7,500,000  , adjusted for Indexation'),
#  Document(page_content='Indexation           plus the amount of any     amount of such Employee Bonus Costs excluded'),
#  Document(page_content='Costs excluded pursuant to this Article   3.1(h)              (i)     All registration   and'),
#  Document(page_content='registration   and administration   fees     payable to the FIA by a     Power Unit   Manufacturer'),
#  Document(page_content='Manufacturer     in relation to   the registration and homologation of   its   Power Units in'),
#  Document(page_content='Power Units in   respect of     the Championship taking place in the applicable Reporting Period'),
#  Document(page_content='Reporting Period      (j)     All   F  in  ancial Penalties     in respect of any breach of   these'),
#  Document(page_content='breach of   these   Power Unit   Financial   Regulations        (k)     All amounts of'),
#  Document(page_content='All amounts of depreciation,   amortisation, impairment loss  ,     and amounts as a result'),
#  Document(page_content='as a result   of revaluation or disposal of tangible assets and intangible assets        (l)'),
#  Document(page_content='(l)     All foreign exchange gains and losses     recognised in profit or loss  , whether'),
#  Document(page_content='or loss  , whether arising from   settlement and/or re  -  measurement of monetar  y items'),
#  Document(page_content='of monetar  y items denominated in a foreign   currency, or otherwise        (m)     Where a'),
#  Document(page_content='(m)     Where a Reporting Group Entity is required     by   applicable   law  s     to pay'),
#  Document(page_content='law  s     to pay employer       social   security   contributions  , the amount by which such'),
#  Document(page_content='by which such mandatory contributions exceed   13.8  % of the Total Employee   Remuneration'),
#  Document(page_content='Formula 1 Power Unit Financial Regulations     7     16 August     2022     © 202  2'),
#  Document(page_content='© 202  2                Issue   1           (n)     All   Health   A  nd   S  afety     Costs'),
#  Document(page_content='afety     Costs        (o)     With respect to Customer Team Power Unit Activities:     (i)'),
#  Document(page_content='(i)     All costs Directly Attributable to Customer Team Power Unit Activities  and     (ii)'),
#  Document(page_content='and     (ii)     If a Power Unit Manufacturer can prove to the satisfaction of the Cost Cap'),
#  Document(page_content='of the Cost Cap   Administration that an identifiable portion of the following costs relates to'),
#  Document(page_content='costs relates to   Customer Team Power Unit Activities, that portion of those costs:     (A)'),
#  Document(page_content='(A)       contributions incurred in respect of  ,     any P  ersonnel engaged in Power   Unit'),
#  Document(page_content='in Power   Unit Activities      (B)     e  lectricity, gas and water costs incurred in the course'),
#  Document(page_content='in the course of Power Unit   Activities      (C)     lease costs in respect of plant and equipment'),
#  Document(page_content='plant and equipment used in the course of   Power Unit Activities  and     (D)     costs of parts'),
#  Document(page_content='costs of parts and consumables, and   outsourced services, incurred for   the maintenance of an'),
#  Document(page_content='maintenance of an item of plant or equipment used in the course   of Power Unit Activities      (p)'),
#  Document(page_content='Activities      (p)     With respect to Current Generation Power Unit Activities     and   in'),
#  Document(page_content='and   in respect of the Full   Year Reporting Periods ending on 31 December     2023, 31'),
#  Document(page_content='2023, 31 December 2024 and 31   December 2025     only  :     (i)     All costs Directly'),
#  Document(page_content='All costs Directly Attributable to Current Generation Power Unit Activities  and     (ii)     If'),
#  Document(page_content='(ii)     If   a     Power Unit Manufacturer can prove to the satisfaction of the Cost Cap'),
#  Document(page_content='of the Cost Cap   Administration that an identifiable portion of the following costs relates to'),
#  Document(page_content='costs relates to   Current Generation   Power Unit Activities, that portion of those     costs:'),
#  Document(page_content='costs:     (A)     Consideration provided to, and assoc    curity   contributions incurred in'),
#  Document(page_content='incurred in respect of  ,     any Personnel engaged in     Power   Unit Activities      (B)     e'),
#  Document(page_content='(B)     e  lectricity, gas and water costs incurred in the course of Power Unit   Activities'),
#  Document(page_content='Unit   Activities      (C)     lease costs in respect of plant and equipment used in t  he course'),
#  Document(page_content='in t  he course of   Power Unit Activities  and     (D)     costs of parts and consumables, and'),
#  Document(page_content='consumables, and outsourced services, incurred for   the maintenance of an item of plant or'),
#  Document(page_content='an item of plant or equipment used in the course   of Power Unit Activities        (q)     A  ll'),
#  Document(page_content='(q)     A  ll   Employee     Termination Benefits     (together with   associated employer'),
#  Document(page_content='employer    security contributions  )  , incurred in the Full Year Reporting Periods ending on 31'),
#  Document(page_content='ending on 31   December   2023  , 31 December 2024     and 31 December   2025    and        Formula'),
#  Document(page_content='and        Formula 1 Power Unit Financial Regulations     8     16 August     2022     © 202  2'),
#  Document(page_content='© 202  2                Issue   1           (r)     All costs of Consideration other than'),
#  Document(page_content='other than Employee Termination Benefits (together with   asso    Employee prior to the date on'),
#  Document(page_content='to the date on which they became a Reassigned Employee, subject to   a maximum aggregate amount of'),
#  Document(page_content='aggregate amount of US Dollars 3,000,000  , adjusted for Indexation  .        3.2     If a cost'),
#  Document(page_content='3.2     If a cost within Total     Costs of the Reporting Group is   Directly Attributable to any'),
#  Document(page_content='Attributable to any combination   of the following activities  :     (a)     Marketing Activities'),
#  Document(page_content='Activities       (b)     Heritage Asset Activities       (c)     Non  -  Power Unit   Activities'),
#  Document(page_content='Activities       (d)     Human Resource  s     Activities       (e)     Finance Activities'),
#  Document(page_content='Activities      (f)     Legal Activities        (g)     C  ustomer   T  eam   Power Unit Activities'),
#  Document(page_content='Unit Activities    and     (h)     C  urrent   G  eneration P  ower Unit Activities  ,      such'),
#  Document(page_content=',      such cost shall be an Excluded Cost.      3.3     For the purposes of this Article 3, where'),
#  Document(page_content='Article 3, where a     Power Unit Manufacturer     has a Presentation   Currency other than US'),
#  Document(page_content='other than US Dollars  ,     amount  s     expresse  d in US Dollars shall be converted into that'),
#  Document(page_content='into that   Power Unit Manufacturer       4.     ADJUSTMENTS     4.1     Unless stated otherwise in'),
#  Document(page_content='stated otherwise in this Article   4  , i  n calculating Relevant Costs, the following   a'),
#  Document(page_content='the following   a  djustments   to Total Costs   of the Reporting Group   must   be made:     (a)'),
#  Document(page_content='be made:     (a)     Related Party Transactions, Exchange Transactions     and   F1   Team'),
#  Document(page_content='and   F1   Team Transactions:     A  ny   Related Party Transaction  , Exchange Transaction'),
#  Document(page_content='Transaction     or F1   Team Transaction     in   connection with   a     Power Unit   Activity'),
#  Document(page_content='Unit   Activity     must be   includ  ed in Relevant Costs   at     not     less   than   Fair'),
#  Document(page_content='less   than   Fair Value.        (b)     Offsetting of   i  ncome and   c  osts  :     If   a'),
#  Document(page_content='osts  :     If   a Reporting Group   Entity   has offset   any   income or   gains     within'),
#  Document(page_content='gains     within   its     Total     Costs,   or any   costs or losses     within   its   revenue,'),
#  Document(page_content='its   revenue,     the   Power Unit Manufacturer     must make an   upward   adjustment     in'),
#  Document(page_content='in     the     calculation of     Relevant Costs to gross up   these     amounts, unless  :'),
#  Document(page_content='unless  :     (i)     such offsetting is permitted under   its     applicable accounting standards'),
#  Document(page_content='standards  ,   with   the exception of     any   income from a government incentive scheme   in'),
#  Document(page_content='scheme   in respect   of certain research and development costs included within Total Costs'),
#  Document(page_content='Total Costs     that   has been offset against such costs     in which case   the Power Unit'),
#  Document(page_content='the Power Unit   Manufacturer      Formula 1 Power Unit Financial Regulations     9     16 August'),
#  Document(page_content='9     16 August     2022     © 202  2                Issue   1           must make an upward'),
#  Document(page_content='must make an upward adjustment in the calculation of Relevant Costs to gross   up these amounts'),
#  Document(page_content='these amounts        or      (ii)     f  inance income   ha  s     be  en     offset against'),
#  Document(page_content='offset against Finance Costs, provided   that any   exclusion made pursuant to Article   3.1(c)'),
#  Document(page_content='to Article   3.1(c)     is made net of finance income    or     (iii)     t  ax credits in respect'),
#  Document(page_content='credits in respect of   C  orporate   Income T  ax   have     be  e  n     offset against tax'),
#  Document(page_content='against tax   charges in respect   of   C  orporate   Income T  ax, provided   that any exclusion'),
#  Document(page_content='that any exclusion made   purs  uant to Article   3.1(d)     is made net of tax credits     in'),
#  Document(page_content='tax credits     in respect of Corporate   Income Tax  .     (c)     Research and Development   c'),
#  Document(page_content='Development   c  osts  :        (i)     All costs     in respect of     Research and Development'),
#  Document(page_content='and Development   for     Power Unit   Activities     must be included in Relevant Costs   in'),
#  Document(page_content='Costs   in     the Reporting Period in which they are   incurred.     (ii)     If     a Reporting'),
#  Document(page_content='If     a Reporting Group Entity   has   defer  red     recognition of   any costs   in respect of'),
#  Document(page_content='in respect of     Research and Development   for   Power Unit   Activities   to   a'),
#  Document(page_content='to   a     subsequent   Reporting Period,   an adjustment     must be made   in     the'),
#  Document(page_content='made   in     the calculation of Relevant   Costs   to ensure such costs are   recognised   with'),
#  Document(page_content='recognised   with  in   the Reporting Period in which   they are incurred  .        (d)'),
#  Document(page_content='.        (d)     Capitalisation of   Power Units  :     If a Reporting Group Entity has'),
#  Document(page_content='Group Entity has capitalised any costs   in respect   of   a Power Unit     during   the Reporting'),
#  Document(page_content='the Reporting Period, an adjustment must be made in the calculation of Relevant Costs   to ensure'),
#  Document(page_content='Costs   to ensure such costs are recognised within the Reporting Period in which they are'),
#  Document(page_content='in which they are   incurred.     (e)     Capital Expenditure  :     (i)     The amount (if any) by'),
#  Document(page_content='amount (if any) by which   the Capital Expenditure Amount     for     the Full Year   Reporting'),
#  Document(page_content='Year   Reporting Period exceeds the Capital Expenditure   Limit     must be included in   the'),
#  Document(page_content='included in   the calculation of Relevant Costs  .     (ii)     If the costs incurred as part of a'),
#  Document(page_content='as part of a Related Party Transaction, Exchange   Transaction or   F1 Team     Transaction meet'),
#  Document(page_content='Transaction meet the definition of paragraphs (a) or   (b) of the definition of Capital'),
#  Document(page_content='of Capital Expenditure, such costs must be included in   Capital Expenditure at not less   than'),
#  Document(page_content='at not less   than Fair Value.     (f)     Inventories  :     (i)     I  f the accounting treatment'),
#  Document(page_content='treatment of   I  nventories     within Total Costs   of the Reporting   Group   varies from the'),
#  Document(page_content='varies from the   following   requirements  , the   Power Unit Manufacturer     must make an   a'),
#  Document(page_content='must make an   a  djustment in the calculation of Relevant Costs     to reflect   these'),
#  Document(page_content='reflect   these   requirements  :     (A)     the cost of an item of Used Inventories must be'),
#  Document(page_content='Inventories must be recognised in full as   an expense in   the Full Year Reporting Period   in'),
#  Document(page_content='Period   in which it was first used   in respect of the     , provided      Formula 1 Power Unit'),
#  Document(page_content='1 Power Unit Financial Regulations     10     16 August     2022     © 202  2                Issue'),
#  Document(page_content='Issue   1           that where such use occurs p  rior to 1 January   of its N  -  3'),
#  Document(page_content='of its N  -  3 Full Year   Reporting Period and the item is re  -  used during the N  -  3 Full'),
#  Document(page_content='the N  -  3 Full Year   Reporting Period  , the cost of that item of Used Inventories must be'),
#  Document(page_content='must be   recognised in full as an expense     in the   N  -  3   Full Year Reporting Period'),
#  Document(page_content='Period        (B)     the cost of     an item of Unused Inventories must not be recognised in   the'),
#  Document(page_content='recognised in   the Reporting Period  and     (C)     the cost of   an item of   Redundant'),
#  Document(page_content='item of   Redundant Inventories   (which has not been   recognised in a previous Full Year'),
#  Document(page_content='previous Full Year Reporting Period pursuant to any   other provision of this Article 4.1(f)(i  ))'),
#  Document(page_content='4.1(f)(i  ))   must be recognised in full as an   expense in the Reporting Period.   W  here'),
#  Document(page_content='Period.   W  here practicable, the identification   of Redundant Inventories must be carried out on'),
#  Document(page_content='be carried out on an item  -  by  -  item   basis. Otherwise, groups of similar items may be'),
#  Document(page_content='items may be considered   together  .        (ii)     T  he cost of   an item of   I  nventories'),
#  Document(page_content='of   I  nventories must comprise  :        (A)     all costs of purchase  ,   determined     on the'),
#  Document(page_content='on the same basis as that used by   the   Power Unit Manufacturer     in its Audited Annual'),
#  Document(page_content='its Audited Annual Financial   Statements     in respect of the previous Full Year Reporting Period'),
#  Document(page_content='Reporting Period           (B)     costs of conversion     (  including fixed production overheads'),
#  Document(page_content='overheads allocated on   a basis that is appropriate to the nature of the product and method of'),
#  Document(page_content="and method of   production and on the basis of the entity's normal level of activity, and   applied"),
#  Document(page_content='and   applied consistently from o  ne   R  eporting   P  eriod to another)      a  nd      (C)'),
#  Document(page_content='a  nd      (C)     other costs incurred in bringing the   item of   I  nventories to   its'),
#  Document(page_content='to   its   present   location and condition  .     (iii)        In the event that an item of'),
#  Document(page_content='that an item of Redundant Inventories:     (A)     has     not been used    and     (B)     is not'),
#  Document(page_content='(B)     is not     of     a technical specification that is     specific to the Power Units'),
#  Document(page_content='the Power Units   supplied to either the Nominated Team or any     one     Customer Team     of'),
#  Document(page_content='Team     of   the Power Unit Manufacturer    and     (C)     its cost   has     been   recognised'),
#  Document(page_content='been   recognised in full as an expense     in the Reporting   Period pursuant to paragraph'),
#  Document(page_content='to paragraph (i)(C) of this Article  ,     the agg  regate cost of all such items   must be'),
#  Document(page_content='items   must be allocated on a  n equal     pro  -  rata   basis across the Nominated Team and'),
#  Document(page_content='Team and   each     Customer Team of the Power Unit   Manufacturer. The Power Unit Manufacturer'),
#  Document(page_content='Unit Manufacturer must then make a downward   adjustment in the calculation of Relevant Cost  s for'),
#  Document(page_content='Cost  s for the Reporting Period equal   to the   aggregate   amount allocated to the Customer'),
#  Document(page_content='to the Customer     Teams.     (iv)     In the event   that   an item of   Redundant Inventories'),
#  Document(page_content='Inventories     written off in a previous   Reporting Period pursuant to paragraph   (i)(  C  )'),
#  Document(page_content='(i)(  C  )     of this Article is used in a   subsequent Reporting Period, the   Power Unit'),
#  Document(page_content='the   Power Unit Manufacturer     must make an   adjustment in the calculation of Relevant Costs'),
#  Document(page_content='of Relevant Costs for that subsequent Reporting      Formula 1 Power Unit Financial Regulations'),
#  Document(page_content='Regulations     11     16 August     2022     © 202  2                Issue   1           Period to'),
#  Document(page_content='Period to add an amount equal to that written off in the previous Reporting   Pe  riod.'),
#  Document(page_content='Pe  riod.        (g)     Unrecorded costs or losses:     If     costs or     losses   incurred by'),
#  Document(page_content='incurred by a Reporting Group Entity are not   recognised     within its   Total Costs,   which'),
#  Document(page_content='Costs,   which under the applicable accounting standards should have been   recognised within'),
#  Document(page_content='recognised within profit or loss     during the Reporting Per  iod  ,   an adjustment must be'),
#  Document(page_content='must be   made in the calculation of Relevant Costs to ensure such costs are recognised     within'),
#  Document(page_content='within     Relevant Costs   for     the Reporting Period  .     (h)     Foreign   e  xchange'),
#  Document(page_content='e  xchange   t  ransaction   c  osts:     (i)     Subject to Article   4.1(h)(ii)  , if a'),
#  Document(page_content='4.1(h)(ii)  , if a Reporting Group Entity incurs a cost for a   transaction in a currency other'),
#  Document(page_content='in a currency other than   the   Power Unit Manufacturer       Presentation Currency, the   Power'),
#  Document(page_content='the   Power Unit Manufacturer     may choose     to make   an     adjustment in the calculation of'),
#  Document(page_content='the calculation of Relevant Costs     to reflect     the difference   between     such cost'),
#  Document(page_content='such cost     retranslated     into   the   Power Unit Manufacturer    Presentation Currency'),
#  Document(page_content='Currency using the Applicable Rate,   and     the value at which those   costs were recorded on ini'),
#  Document(page_content='recorded on ini  tial recognition within     Total Costs     of the Reporting   Group  .     (ii)'),
#  Document(page_content='Group  .     (ii)     If a     Power Unit Manufacturer     chooses to make such an adjustment, it'),
#  Document(page_content='an adjustment, it must be   made for all costs within Total Costs     of the Reporting Group'),
#  Document(page_content='Reporting Group     that have been   transacted in all currencies other than the   Power Unit'),
#  Document(page_content='the   Power Unit Manufacturer    Presentation Currency  , unless any such costs have otherwise been'),
#  Document(page_content='have otherwise been excluded   from Total Costs of the Reporting Group pursuant to Article 3  .'),
#  Document(page_content='to Article 3  .     (i)     Eligible External Manufacturing Costs  :     If a     Power Unit'),
#  Document(page_content='If a     Power Unit Manufacturer     has   recognised     Eligible External Manufacturing Costs'),
#  Document(page_content='Costs   within Total Costs   of   the     Reporting Group  ,   it     must make a downward'),
#  Document(page_content='make a downward adjustment in   the calculation     of Relevant Costs     equal to   35% of     any'),
#  Document(page_content='to   35% of     any Eligible External Manufacturing   Costs     recognised  , subject to a maximum'),
#  Document(page_content='to a maximum amount of  :     (i)     US Dollars 20,000,000   in respect of   each of   the Full'),
#  Document(page_content='each of   the Full Year Reporting Periods   ending on 31 December 2023, 31 December 2024 and 31'),
#  Document(page_content='2024 and 31 December 2025  ,   adjusted for Indexation    and     (ii)     US Dollars 30,000,000,'),
#  Document(page_content='Dollars 30,000,000, adjusted for Indexation  ,   in respect of the Full Year   Reporting Period'),
#  Document(page_content='Reporting Period ending on 31 December 2026 and   in respect of   each   subsequent Full Year'),
#  Document(page_content='Full Year Reporting Period.     (j)     Election to defer:     (i)     In respect of     e  ach'),
#  Document(page_content='of     e  ach     of   the Full Year Reporting Period  s     ending on 31 December   2023   and'),
#  Document(page_content='2023   and     31 December 2  024  ,   a     Powe  r Unit Manufacturer may choose to make   an'),
#  Document(page_content='choose to make   an upward   a  djustment in the calculation of Relevant Costs     up to a maximum'),
#  Document(page_content='up to a maximum   amount of US Dollars 15,000,000  , adjusted for Indexation  .        Formula 1'),
#  Document(page_content='.        Formula 1 Power Unit Financial Regulations     12     16 August     2022     © 202  2'),
#  Document(page_content='© 202  2                Issue   1           (ii)     If a Power Unit Manufacturer make  s'),
#  Document(page_content='make  s     an   a  djustment pursuant to Article 4.1(j)(i)     within its Full Year Reporting'),
#  Document(page_content='Full Year Reporting Documentation that is submitted to Cost Cap   Administration  :     (A)     it'),
#  Document(page_content=':     (A)     it cannot retrospectively be reversed    and     (B)     the     Power Unit'),
#  Document(page_content='Power Unit     Manufacturer   must make an equal and opposite   downward     a  djustment in'),
#  Document(page_content='a  djustment in the calculation of Relevant Costs     for     the   subsequent Full Year'),
#  Document(page_content='Full Year Reporting Pe  r  iod  .     (k)     New Power Unit Manufacturers  :     A   Power Unit'),
#  Document(page_content='A   Power Unit Man  u  facturer that  ,     as at the end of the applicable Reporting Period'),
#  Document(page_content='Reporting Period   meets the   definition of a New Power Unit Manufacturer  ,     must make a'),
# ...
#  Document(page_content='incomplete     or misleading         (f)     failing to c  omply with the terms of an ABA'),
#  Document(page_content='of an ABA       (g)     failing to   comply with     the requirements of Article  s     1.8  ,'),
#  Document(page_content='s     1.8  ,   1.9     or   1.10        (h)     failing to submit information or documentation'),
#  Document(page_content='or documentation required by any Determination by the   applicable deadline included in that'),
#  Document(page_content='included in that Determination    or     (i)     f  ailing to submit a     Power Unit   Used'),
#  Document(page_content='Power Unit   Used Inventory Incremental List   in the format   prescribed   and by the applicable'),
#  Document(page_content='by the applicable deadline set by   the Cost Cap Administration from   time to time via a'),
#  Document(page_content='time to time via a Determination  .     8.3     In the event the Cost Cap Adjudication Panel'),
#  Document(page_content='Adjudication Panel determines that a     Power Unit Manufacturer     has   committed     a'),
#  Document(page_content='committed     a Procedural Breach, the   Cost Cap Adjudication Panel   shall   impose a Financial'),
#  Document(page_content='impose a Financial   Penalty  , unless  :     (a)     the Cost Cap Adjudication Panel determines'),
#  Document(page_content='Panel determines that   sufficient mitigating factors   exist   to   justify taking   no further'),
#  Document(page_content='taking   no further action    or     (b)     the Cost Cap Adjudication Panel determines that a'),
#  Document(page_content='determines that a sufficient a  ggravating factor(s) exist, in   which case it shall impose a Minor'),
#  Document(page_content='impose a Minor Sporting Penalty in addition to the Financial Penalty, or   in lieu of the Financial'),
#  Document(page_content='of the Financial Penalty.     Late and Non  -  Submission     of Full Year Reporting Documentation'),
#  Document(page_content='Documentation     8.4     In the event that a     Power Unit Manufacturer     does not submit the'),
#  Document(page_content='not submit the   Full Year   Reporting   Documentation by the   Full Year   Reporting Deadline (a'),
#  Document(page_content='Deadline (a   "  Late Submission  "  ), the Cost Cap   Administration     shall issue a late'),
#  Document(page_content='shall issue a late submission notice (  "  Late Submission Notice  "  ) to the   Power   Unit'),
#  Document(page_content='the   Power   Unit Manufact  urer     (the   "  Late Submitting   Manufacturer  "  ).     8.5'),
#  Document(page_content='"  ).     8.5     Each Late Submitting   Manufacturer     shall, within   48     hours of receipt'),
#  Document(page_content='hours of receipt of the Late Submission   Notice,   provide   the Cost Cap   Administration'),
#  Document(page_content='Administration     with a written explanation of   the reasons for its   Late Submission  .'),
#  Document(page_content='Submission  .      8.6     The Cost C  ap   Administration     may     grant the Late Submitting'),
#  Document(page_content='Late Submitting   Manufacturer     an extension to the   Full Year   Reporting Deadline'),
#  Document(page_content='Deadline     provided that it is satisfied with the written explanation pursuant   to Article   8.5'),
#  Document(page_content='to Article   8.5     (the   "  Extended   Reporting   Deadline  "  )  .     8.7     In the event'),
#  Document(page_content='In the event that     a Late Submitting   Manufacturer  :      (a)     does not   provide a'),
#  Document(page_content='not   provide a written response   to a Late Submission Notice   within the specified   time'),
#  Document(page_content='time              Formula 1 Power Unit Financial Regulations     25     16 August     2022     ©'),
#  Document(page_content='2022     © 202  2                Issue   1           (b)     provide  s     a written response'),
#  Document(page_content='a written response to a Late Submission     Notice     within the specified time   but   such'),
#  Document(page_content='time   but   such response   is deemed unsatisfactory by the Cost Cap Administration      or'),
#  Document(page_content='or      (c)     does not submit the   Full Year   Reporting Documentation by the Extended'),
#  Document(page_content='by the Extended   Reporting   Deadline,      the Late Sub  mitting   Manufacturer     shall have'),
#  Document(page_content='shall have committed a Non  -  Submission Breach and shall   be immediately referred to the'),
#  Document(page_content='referred to the Cost Cap Adjudication Panel.     8.8     A     Power Unit Manufacturer     that'),
#  Document(page_content='that submits a Subset Cost Cap Reporting Template as part of its   Full Year Reporting'),
#  Document(page_content='Full Year Reporting Documenta  tion   when     such   Power Unit Manufacturer     has     failed to'),
#  Document(page_content='has     failed to meet   the applicable deadlines     in order to use     Subset Accounts'),
#  Document(page_content='Subset Accounts stipulated by the Cost Cap   Administration via   a   Determination shall have'),
#  Document(page_content='shall have committed a Non  -  Submission Breach.      8.9     In the event the Cost Cap'),
#  Document(page_content='the Cost Cap   Adjudication Panel determines that a     Power Unit Manufacturer     has   committed'),
#  Document(page_content='has   committed     a Non  -  Submission Breach, the Cost Cap Adjudication Panel shall impose a'),
#  Document(page_content='shall impose a        in accordance with Article     9.1(c)(i)   and   additionally   may impose'),
#  Document(page_content='may impose   a Financial Penalty   and/or any   other   Material Sporting Penalties  .     Minor'),
#  Document(page_content='.     Minor Overspend Breach     8.10     A "  Minor Overspend Breach  " arise  s     when:'),
#  Document(page_content='s     when:     (a)     a     Power Unit Manufacturer     submits its Full Year Reporting'),
#  Document(page_content='Full Year Reporting Documentation and   Relevant Costs   reported therein   exceed the   Power Unit'),
#  Document(page_content='the   Power Unit   Cost Cap by   less     than 5%  or     (b)     f  ollowing the review of a'),
#  Document(page_content='the review of a     Power Unit Manufacturer    Documentation (including, where applicable, the'),
#  Document(page_content='applicable, the conclusion of any   investigation   undertaken by the Cost Cap   Administration'),
#  Document(page_content='Administration     and/or the Independent Audit Firm   appointed by the Cost Cap   Administration'),
#  Document(page_content='Administration  ),     the   Power Unit Manufacturer    Relevant   Costs have been   determined'),
#  Document(page_content='been   determined   to exceed the   Power Unit   Cost Cap by   less     than 5%.     8.11     In'),
#  Document(page_content='5%.     8.11     In the event the Cost Cap Adjudication Panel determines that   a     Power Unit'),
#  Document(page_content='a     Power Unit Manufacturer     has   committed     a Minor Overspend Breach, the Cost Cap'),
#  Document(page_content='the Cost Cap Adjudication Panel   may   impose a   Financial Penalty and/or a  ny Minor Sporting'),
#  Document(page_content='ny Minor Sporting Penalties  .     Material Overspend Breach     8.12     A "  Material Overspend'),
#  Document(page_content='Material Overspend Breach  " arise  s     when:     (a)     a     Power Unit Manufacturer'),
#  Document(page_content='Manufacturer     submits its Full Year Reporting Documentation and   Relevant Costs     reported'),
#  Document(page_content='Costs     reported therein     exceed the   Power Unit   Cost Cap by   5%     or more    or     (b)'),
#  Document(page_content='more    or     (b)     f  ollowing the review of a     Power Unit Manufacturer    Documentation'),
#  Document(page_content='Documentation (including, wh  ere applicable, the conclusion of any   investigation   undertaken'),
#  Document(page_content='undertaken by the Cost Cap   Administration     and/or the Independent Audit Firm   appointed by'),
#  Document(page_content='Firm   appointed by the Cost Cap   Administration  ),     the   Power Unit Manufacturer    Relevant'),
#  Document(page_content='Relevant   Costs have been   determined   to exceed the   Power     Unit   Cost Cap by   5%'),
#  Document(page_content='Cap by   5%     or more  .     8.13     In the event the Cost Cap Adjudication Panel determines'),
#  Document(page_content='Panel determines that   a Power Unit Manufacturer   has   committed     a Material Overspend'),
#  Document(page_content='Material Overspend Breach, the Cost Cap Adjudication Panel shall impose a        Formula 1 Power'),
#  Document(page_content='Formula 1 Power Unit Financial Regulations     26     16 August     2022     © 202  2'),
#  Document(page_content='© 202  2                Issue   1                in accordance with Article     9.1(c)(i)   and'),
#  Document(page_content='9.1(c)(i)   and   additionally   may impose a Financial Penalty and/  or   any   other   Material'),
#  Document(page_content='other   Material Sporting Penalt  ies  .     Aggravating or mitigating factors     8.14     In'),
#  Document(page_content='8.14     In determining the sanctions appropriate for a particular case,     the Cost Cap'),
#  Document(page_content='the Cost Cap Adjudication   Panel   shall take into account any aggravating or mitigating'),
#  Document(page_content='or mitigating factors.      8.15     Examples of aggravating factors include:     (a)     any e'),
#  Document(page_content='(a)     any e  lement of   bad faith,   dishonesty, wilful concealment or fraud      (b)     m'),
#  Document(page_content='(b)     m  ultiple breaches of the  se     Power Unit   Financial Regulations     in   the'),
#  Document(page_content='in   the Reporting   Period     in question        (c)     breaches of these   Power Unit'),
#  Document(page_content='Power Unit   Financial Regulations in respect of a previous Reporting   Period      (d)     q'),
#  Document(page_content='(d)     q  uantum of breach of the   Power Unit   Cost Cap    and     (e)     f  ailure to co'),
#  Document(page_content='f  ailure to co  -  operate with     the Cost Cap   Administration     and/or Independent Audit'),
#  Document(page_content='Independent Audit Firm     appoint  ed by the Cost Cap   Administration  .     8.16     Examples of'),
#  Document(page_content='Examples of mitigating factors include:     (a)     voluntary disclosure of a breach   to the'),
#  Document(page_content='a breach   to the Cost Cap   Administration        (b)     t  rack record of compliance with the'),
#  Document(page_content='with the  se     Power Unit   Financial Regulations     in previous   Reporting P  eriods      (c)'),
#  Document(page_content='P  eriods      (c)     u  nforeseen Force Majeure Events    and     (d)     f  ull and unfettered'),
#  Document(page_content='and unfettered   co  -  operation     with     the   Cost Cap   Administration     and/or   the'),
#  Document(page_content='and/or   the   Independent Audit Firm     appointed by the Cost Cap   Administration  .     9.'),
#  Document(page_content='.     9.     SANCTIONS FOR BREACH     Sanctions     9.1     The following sanctions may be imposed'),
#  Document(page_content='may be imposed for breach of these   Power Unit   Financial Regulations     as set out in Article'),
#  Document(page_content='out in Article   8  :     (a)     A "  Financial Penalty  ", meaning     a fine     in an amount'),
#  Document(page_content='in an amount   to be determined on a case by   case basis  .     (b)     A "  Minor Sporting'),
#  Document(page_content='A "  Minor Sporting Penalty  ", meaning one or more of the following:     (i)     public reprimand'),
#  Document(page_content='public reprimand      (ii)     deduction of       points awarded to the Nominated Team of   the'),
#  Document(page_content='Team of   the relevant Power Unit      Formula 1 Power Unit Financial Regulations     27     16'),
#  Document(page_content='27     16 August     2022     © 202  2                Issue   1           Manufacturer for the'),
#  Document(page_content='for the Championship that took place within the Reporting   Period of the breach      (iii)'),
#  Document(page_content='(iii)     deduction of       points awarded to the Nominated Team and   to all     Customer'),
#  Document(page_content='to all     Customer Teams of the   relevant Power Unit Manufacturer for the Championship that took'),
#  Document(page_content='that took place   within the Reporting Period of the   breach      (iv)     l  imitations on   the'),
#  Document(page_content='on   the   ability t  o   conduct   Power Unit Test Bench   testing   or other   T  esting     in'),
#  Document(page_content='T  esting     in respect of Power Units   to be   homologated for supply to   F1 Teams   in'),
#  Document(page_content='to   F1 Teams   in respect of the Championships taking place from 2026 onwards        and/  or'),
#  Document(page_content='and/  or     (v)     r  eduction of the   Power Unit   Cost Cap,     provided that     the'),
#  Document(page_content='that     the penalty specified in Article     9.1(b)  (v)     shall only   be applied   with'),
#  Document(page_content='be applied   with   respect   to   the   Full Year Reporting Period   immediately     following the'),
#  Document(page_content='following the   date of the   imposition of the sanction     (and subsequent   Full Year'),
#  Document(page_content='Full Year Reporting Periods  , where   applicable)    and     provided that the penalties'),
#  Document(page_content='that the penalties specified in     Articles 9.1(b)(ii)   and   9.1(b)(iii) can  not   be   applied'),
#  Document(page_content='not   be   applied   prior to 1 January 2026  .     (c)     A "  Material   Sporting Penalty  ",'),
#  Document(page_content='Penalty  ", meaning one or more of the following:     (i)     deduction of       points awarded to'),
#  Document(page_content='points awarded to the Nominated Team of the relevant Power Unit   Manufacturer for the'),
#  Document(page_content='for the Championship that took place within the Repor  ting   Period of the breach      (ii)'),
#  Document(page_content='(ii)     deduction of       points awarded to the Nominated Team and to all Customer Teams of'),
#  Document(page_content='Customer Teams of the   relevant Power Unit Manufacturer for the Championship that took place'),
#  Document(page_content='that took place   within the Reporting     Period of the breach      (iii)     l  imitations on the'),
#  Document(page_content='imitations on the ability to conduct     Power Unit Test Bench   testing     or other   T  esting'),
#  Document(page_content='other   T  esting     in respect of Power Units to be homologated for supply to F1 Teams   in'),
#  Document(page_content='to F1 Teams   in respect of the Championships taking place from 2026 onwards        (iv)'),
#  Document(page_content='(iv)     limitations on the ability to make future upgrades to the specification of the'),
#  Document(page_content='of the   Power Unit   that is currently   homologated     for supply to F1 Teams        (v)'),
#  Document(page_content='(v)     divesting of right for its Power Units to be homologated for supply to F1 Teams   in'),
#  Document(page_content='to F1 Teams   in respect of any Championship s  easons from 2026 onwards        or     (vi)     r'),
#  Document(page_content='or     (vi)     r  eduction of the   Power Unit   Cost Cap,     provided that     the penalty'),
#  Document(page_content='the penalty specified in Article     9.1(c)  (v  i  )     shall only   be applied   with'),
#  Document(page_content='be applied   with   respect to   the   Full Year Reporting     Period   immediately     following'),
#  Document(page_content='following the     date of the     imposition of the sanction     (and subsequent   Full Year'),
#  Document(page_content='Full Year Reporting Periods  , where   applicable  )    and        Formula 1 Power Unit Financial'),
#  ...]

# %% [markdown]
# Arriba, realizamos algunos fragmentos utilizando Langchain, un marco popular para crear aplicaciones utilizando modelos de lenguaje grandes. En los métodos anteriores, viste varios ejemplos de chunking. Langchain puede ayudar a hacer que el proceso de chunking sea más fácil con algunos de sus métodos. Estos métodos incluyen fragmentos de tamaño fijo, así como fragmentación recursiva, que acabamos de ver.
#
# Por ejemplo, existe CharacterTextSplitter que dividirá el texto dado en un fragmento de tamaño fijo de un tamaño dado y un solapamiento de caracteres dado.
#
# RecursiveCharacterTextSplitter divide el texto en fragmentos más pequeños de manera iterativa. Nuevamente, puedes proporcionar el tamaño del fragmento y el recuento de solapamiento del fragmento.

# %% [markdown]
# El chunking es una técnica importante por muchas razones. Ayuda a evitar el límite de tokens cuando se trabaja con grandes cantidades de datos y también optimiza la respuesta que recibimos del modelo. Encontrar la técnica de fragmentación adecuada y el tamaño de fragmento es crucial para recibir respuestas relevantes.

# %% [markdown]
# ## Criterios de Éxito
#
# Para completar este desafío con éxito:
#
# * Mostrar comprensión de los tokens y cómo calcularlos.
# * Demostrar comprensión del chunking experimentando con diferentes técnicas.
# * Ser capaz de entender la importancia de encontrar la solución de chunking adecuada según si se captura o no el significado semántico.
